# %% [markdown]
# # Generate tiles with global slide labels
# * Real code in make_global_tiles.py

# %%
import os
import sys
import glob
import random
import pickle
import numpy as np
import pandas as pd
from PIL import Image
from skimage import color
from skimage import filters
from skimage.morphology import disk
from openslide import OpenSlide, OpenSlideUnsupportedFormatError

import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from IPython.display import display, HTML
from sklearn.metrics import accuracy_score

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# Add the src directory for functions
src_dir = os.path.join(os.path.dirname(os.path.dirname(os.getcwd())), 'src')
print(src_dir)
sys.path.append(src_dir)

# import my functions:
from WSI_utils import*

# Base Directory where data is stored
train_folder = '/media/rene/Data/CAMELYON16/TrainingData'
base_out_dir = '/media/rene/Data/camelyon_out'
# Out:
# /media/rene/Data/camelyon/src

# %% [markdown]
# ## Get the average samples per slide
# * Used to calculate the number of samples taken from a given slide

# %%
normal_locs = glob.glob(os.path.join(train_folder, 'Train_Normal/*'))
tumor_locs = glob.glob(os.path.join(train_folder, 'Train_Tumor/*'))
all_locs = normal_locs+tumor_locs

tile_num_list = []

for loc in all_locs:
    wsi = WSI(loc)
    wsi.generate_mask(mask_level=6)
    num_tiles = wsi.est_total_tiles(tile_size = 224)
    tile_num_list.append(num_tiles)
    
average_tiles = np.average(np.array(tile_num_list))
print('average_tiles: ', average_tiles)
print('max tiles: ', np.amax(np.array(tile_num_list)))
print('min tiles: ', np.amin(np.array(tile_num_list)))
# Out:
# average_tiles:  27097.74074074074
# max tiles:  126070.0
# min tiles:  574.0

# %% [markdown]
# ## Create validation set
# * Randomly sample 20% of tumor and non-tumor training set

# %%
np.random.seed(101)
vaild_normal_idx = np.random.choice(160, 32)
valid_tumor_idx = np.random.choice(110, 22)

# %%
average_tiles = 27098
tile_size = 224
base_out_dir = '/media/rene/Data/camelyon_out/basic_tiles_224'


for loc in all_locs[0:1]:
    if 'Normal' in loc:
        wsi_type = 'normal'
        wsi_id = int(loc.rsplit('_', 1)[-1].rsplit('.', 1)[0])
        if wsi_id in vaild_normal_idx:
            ttv = 'valid'
        else:
            ttv = 'train'

    elif 'Tumor' in loc:
        wsi_type = 'tumor'
        wsi_id = int(loc.rsplit('_', 1)[-1].rsplit('.', 1)[0])
        if wsi_id in valid_tumor_idx:
            ttv = 'valid'
        else:
            ttv = 'train'
    else:
        print('Error, not found as normal or tumor')
        
    # now read in and get the samples:
    wsi = WSI(loc)
    wsi.generate_mask(mask_level=6)
    total_tiles = wsi.est_total_tiles(tile_size = 224)
    num_tiles = np.amin([total_tiles, average_tiles/2])
    
    # Make folders for normal, tumor. Save each set of samples from a wsi in a folder within these.
    out_dir = os.path.join(base_out_dir, ttv, wsi_type, wsi.wsi_name)
    if not os.path.exists(out_dir):
        os.makedirs(out_dir)
    # Now make the tiles
    wsi.make_tiles(out_dir, num_tiles, tile_size)

# %% [markdown]
# # Test

# %%
data_loc = '/media/rene/Data/CAMELYON16'

test_loc = os.path.join(data_loc, 'Testset', 'Images')
wsi_locs = glob.glob(os.path.join(test_loc, '*'))

mask_loc = os.path.join(data_loc, 'Testset', 'Ground_Truth', 'Masks')
wsi_mask_locs = glob.glob(os.path.join(mask_loc, '*'))

num_wsi = len(wsi_locs)
num_mask = len(wsi_mask_locs)
num_tumor = num_mask
num_all = num_wsi+num_mask

# find out which masks contain tumor, so can use standard sampling function
tumor_idx = [loc.rsplit('/', 1)[-1].split('_', 1)[1].split('_', 1)[0] for loc in wsi_mask_locs]
tumor_wsi_locs = [loc for loc in wsi_locs if loc.rsplit('_', 1)[-1].rsplit('.', 1)[0] in tumor_idx]
normal_wsi_locs = [loc for loc in wsi_locs if loc.rsplit('_', 1)[-1].rsplit('.', 1)[0] not in tumor_idx]

print('len(tumor_wsi_locs)', len(tumor_wsi_locs))
print('len(normal_wsi_locs)', len(normal_wsi_locs))
print('len(wsi_locs)', len(wsi_locs))
# Out:
# len(tumor_wsi_locs) 49
# len(normal_wsi_locs) 81
# len(wsi_locs) 130

# %%
tumor_frac = .5
num_samples = 25000
ttv = 'test'
out_dir = '/media/rene/Data/camelyon_out/tiles_224_100t'
tile_size = 224
strict = False

normal_tiles_per_wsi = int(np.round((1-tumor_frac)*num_samples/num_all))

# sample from all the normal slides (only normal samples)
normal_tiles_per_wsi = int(np.round((1-tumor_frac)*num_samples/num_all))
for idx, loc in enumerate(normal_wsi_locs):
    print(loc)
    wsi_id = int(loc.rsplit('_', 1)[-1].rsplit('.', 1)[0])
    wsi = WSI(loc)
    out_loc = os.path.join(out_dir, ttv, 'normal')
    if not os.path.exists(out_loc):
        os.makedirs(out_loc)
    wsi.make_test_tiles_by_class(out_loc, num_tiles=normal_tiles_per_wsi, tile_class='normal', 
        tile_size=tile_size, tile_sample_level=0)

# sample from all the tumor slides, both normal and tumor
normal_tiles_per_wsi = int(np.round((1-tumor_frac)*num_samples/num_all))
tumor_tiles_per_wsi = int(np.round(tumor_frac*num_samples/num_tumor))

for idx, loc in enumerate(tumor_wsi_locs):
    print(loc)
    wsi_id = int(loc.rsplit('_', 1)[-1].rsplit('.', 1)[0])
    wsi = WSI(loc)
    out_loc = os.path.join(out_dir, ttv, 'normal')
    if not os.path.exists(out_loc):
        os.makedirs(out_loc)
    wsi.make_test_tiles_by_class(out_loc, num_tiles=normal_tiles_per_wsi, 
        tile_class='normal', tile_size=tile_size, tile_sample_level=0, strict=strict)

    out_loc = os.path.join(out_dir, ttv, 'tumor')
    if not os.path.exists(out_loc):
        os.makedirs(out_loc)
    wsi.make_test_tiles_by_class(out_loc, num_tiles=tumor_tiles_per_wsi, 
        tile_class='tumor', tile_size=tile_size, tile_sample_level=0, strict=strict)
# Out:
# /media/rene/Data/CAMELYON16/Testset/Images/Test_067.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_014.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_025.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_043.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_106.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_047.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_018.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_087.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_062.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_059.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_035.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_078.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_077.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_100.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_072.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_114.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_020.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_103.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_129.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_076.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_045.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_036.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_093.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_063.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_089.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_003.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_085.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_125.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_127.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_091.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_007.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_088.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_096.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_042.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_023.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_041.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_055.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_111.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_012.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_031.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_057.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_126.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_115.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_128.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_022.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_024.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_083.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_005.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_118.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_081.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_130.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_037.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_017.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_058.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_119.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_053.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_006.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_032.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_095.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_044.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_070.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_039.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_050.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_123.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_107.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_098.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_015.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_056.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_109.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_034.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_019.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_124.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_060.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_120.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_101.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_054.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_080.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_028.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_009.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_112.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_086.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_116.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_052.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_094.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_064.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_002.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_071.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_030.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_068.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_066.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_033.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_038.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_051.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_049.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_099.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_074.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_113.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_016.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_082.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_110.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_117.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_013.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_097.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_021.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_001.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_029.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_069.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_061.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_008.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_122.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_084.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_075.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_121.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_040.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_079.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_105.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_102.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_092.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_073.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_065.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_090.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_004.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_108.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_011.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_048.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_026.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_104.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_010.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_046.tif
# /media/rene/Data/CAMELYON16/Testset/Images/Test_027.tif
